# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, Dropout, Flatten, Dense, Input, Layer
from tensorflow.keras.layers import Embedding, LSTM, add, Concatenate, Reshape, concatenate, Bidirectional
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet201
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap

plt.rcParams['font.size'] = 12
sns.set_style("dark")
warnings.filterwarnings('ignore')

# %%
image_path = '/kaggle/input/flikr8k/Flickr8K/Flicker8k_Images'

# %%
data = pd.read_csv("/kaggle/input/flikr8k-caption/captions.txt")
data.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
def readImage(path,img_size=224):
    img = load_img(path,color_mode='rgb',target_size=(img_size,img_size))
    img = img_to_array(img)
    img = img/255.
    
    return img

def display_images(temp_df):
    temp_df = temp_df.reset_index(drop=True)
    plt.figure(figsize = (20 , 20))
    n = 0
    for i in range(15):
        n+=1
        plt.subplot(5 , 5, n)
        plt.subplots_adjust(hspace = 0.7, wspace = 0.3)
        image = readImage(f"/kaggle/input/flikr8k/Flickr8K/Flicker8k_Images/{temp_df.image[i]}")
        plt.imshow(image)
        plt.title("\n".join(wrap(temp_df.caption[i], 20)))
        plt.axis("off")

# %%
display_images(data.sample(15))

# %%
def text_preprocessing(data):
    data['caption'] = data['caption'].apply(lambda x: x.lower())
    data['caption'] = data['caption'].apply(lambda x: x.replace("[^A-Za-z]",""))
    data['caption'] = data['caption'].apply(lambda x: x.replace("\s+"," "))
    data['caption'] = data['caption'].apply(lambda x: " ".join([word for word in x.split() if len(word)>1]))
    data['caption'] = "startseq "+data['caption']+" endseq"
    return data

# %%
data = text_preprocessing(data)
captions = data['caption'].tolist()
captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tri-colored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(captions)
vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(caption.split()) for caption in captions)

images = data['image'].unique().tolist()
nimages = len(images)

split_index = round(0.85*nimages)
train_images = images[:split_index]
val_images = images[split_index:]

train = data[data['image'].isin(train_images)]
test = data[data['image'].isin(val_images)]

train.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

tokenizer.texts_to_sequences([captions[1]])[0]
# Out:
# [1, 18, 315, 63, 195, 116, 2]

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tqdm import tqdm

# Download the weights manually if needed and place them in a known directory
weights_path = '/kaggle/input/densenet201_weights_tf_dim_ordering_tf_kernels.h5/keras/default/1/densenet201_weights_tf_dim_ordering_tf_kernels.h5'

# Load the model with the weights
model = DenseNet201(weights=weights_path)
fe = Model(inputs=model.input, outputs=model.layers[-2].output)

img_size = 224
features = {}
for image in tqdm(data['image'].unique().tolist()):
    img = load_img(os.path.join(image_path, image), target_size=(img_size, img_size))
    img = img_to_array(img)
    img = img / 255.
    img = np.expand_dims(img, axis=0)
    feature = fe.predict(img, verbose=0)
    features[image] = feature
# Out:
#   0%|          | 0/8091 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730536530.203661      69 service.cc:145] XLA service 0x7cb094003bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730536530.203725      69 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1730536543.246992      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100%|██████████| 8091/8091 [12:38<00:00, 10.67it/s]

# %%
class CustomDataGenerator(Sequence):
    
    def __init__(self, df, X_col, y_col, batch_size, directory, tokenizer, 
                 vocab_size, max_length, features,shuffle=True):
    
        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.directory = directory
        self.batch_size = batch_size
        self.tokenizer = tokenizer
        self.vocab_size = vocab_size
        self.max_length = max_length
        self.features = features
        self.shuffle = shuffle
        self.n = len(self.df)
        
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __len__(self):
        return self.n // self.batch_size
    
    def __getitem__(self,index):
    
        batch = self.df.iloc[index * self.batch_size:(index + 1) * self.batch_size,:]
        X1, X2, y = self.__get_data(batch)        
        return (X1, X2), y
    
    def __get_data(self,batch):
        
        X1, X2, y = list(), list(), list()
        
        images = batch[self.X_col].tolist()
           
        for image in images:
            feature = self.features[image][0]
            
            captions = batch.loc[batch[self.X_col]==image, self.y_col].tolist()
            for caption in captions:
                seq = self.tokenizer.texts_to_sequences([caption])[0]

                for i in range(1,len(seq)):
                    in_seq, out_seq = seq[:i], seq[i]
                    in_seq = pad_sequences([in_seq], maxlen=self.max_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=self.vocab_size)[0]
                    X1.append(feature)
                    X2.append(in_seq)
                    y.append(out_seq)
            
        X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                
        return X1, X2, y

# %%
input1 = Input(shape=(1920,))
input2 = Input(shape=(max_length,))

img_features = Dense(256, activation='relu')(input1)
img_features_reshaped = Reshape((1, 256), input_shape=(256,))(img_features)

sentence_features = Embedding(vocab_size, 256, mask_zero=False)(input2)
merged = concatenate([img_features_reshaped,sentence_features],axis=1)
sentence_features = LSTM(256)(merged)
x = Dropout(0.5)(sentence_features)
x = add([x, img_features])
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(vocab_size, activation='softmax')(x)

caption_model = Model(inputs=[input1,input2], outputs=output)
caption_model.compile(loss='categorical_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(caption_model)

# %%
caption_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 1920)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    491,776 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 34)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 256)    │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 34, 256)   │  2,172,160 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 35, 256)   │          0 │ reshape[0][0],    │
# │ (Concatenate)       │                   │            │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 256)       │    525,312 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256)       │          0 │ dropout[0][0],    │
# │                     │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     32,896 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8485)      │  1,094,565 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,316,709 (16.47 MB)
#  Trainable params: 4,316,709 (16.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_generator = CustomDataGenerator(df=train,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

validation_generator = CustomDataGenerator(df=test,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

# %%
model_name = "model.keras"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=1)

earlystopping = EarlyStopping(monitor='val_loss',min_delta = 0, patience = 5, verbose = 1, restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=0.00000001)

# %%
# Train the model and save the history
history = caption_model.fit(
    train_generator,
    epochs=30,
    steps_per_epoch=200,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystopping, learning_rate_reduction]
)
# Out:
# Epoch 1/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 6.3685
# Epoch 1: val_loss improved from inf to 4.78704, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 151s 715ms/step - loss: 6.3652 - val_loss: 4.7870 - learning_rate: 0.0010
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 4.8907
# Epoch 2: val_loss improved from 4.78704 to 4.38881, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 188ms/step - loss: 4.8901 - val_loss: 4.3888 - learning_rate: 0.0010
# Epoch 3/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 121ms/step - loss: 4.5080
# Epoch 3: val_loss improved from 4.38881 to 4.25284, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - loss: 4.4944 - val_loss: 4.2528 - learning_rate: 0.0010
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 4.3508
# Epoch 4: val_loss improved from 4.25284 to 4.11341, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 194ms/step - loss: 4.3506 - val_loss: 4.1134 - learning_rate: 0.0010
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 4.2294
# Epoch 5: val_loss improved from 4.11341 to 4.01416, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 185ms/step - loss: 4.2292 - val_loss: 4.0142 - learning_rate: 0.0010
# Epoch 6/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - loss: 4.1220
# Epoch 6: val_loss improved from 4.01416 to 3.96622, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 4.1156 - val_loss: 3.9662 - learning_rate: 0.0010
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 4.0258
# Epoch 7: val_loss improved from 3.96622 to 3.89229, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 193ms/step - loss: 4.0257 - val_loss: 3.8923 - learning_rate: 0.0010
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 3.9634
# Epoch 8: val_loss improved from 3.89229 to 3.86085, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 194ms/step - loss: 3.9634 - val_loss: 3.8609 - learning_rate: 0.0010
# Epoch 9/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - loss: 3.8827
# Epoch 9: val_loss improved from 3.86085 to 3.81427, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 3.8859 - val_loss: 3.8143 - learning_rate: 0.0010
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 3.8462
# Epoch 10: val_loss improved from 3.81427 to 3.78136, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 185ms/step - loss: 3.8462 - val_loss: 3.7814 - learning_rate: 0.0010
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.8014
# Epoch 11: val_loss improved from 3.78136 to 3.75727, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - loss: 3.8013 - val_loss: 3.7573 - learning_rate: 0.0010
# Epoch 12/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - loss: 3.7545
# Epoch 12: val_loss improved from 3.75727 to 3.73866, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - loss: 3.7522 - val_loss: 3.7387 - learning_rate: 0.0010
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 3.7110
# Epoch 13: val_loss improved from 3.73866 to 3.71568, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 189ms/step - loss: 3.7111 - val_loss: 3.7157 - learning_rate: 0.0010
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.6953
# Epoch 14: val_loss improved from 3.71568 to 3.70954, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 187ms/step - loss: 3.6953 - val_loss: 3.7095 - learning_rate: 0.0010
# Epoch 15/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - loss: 3.6672
# Epoch 15: val_loss did not improve from 3.70954
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - loss: 3.6632 - val_loss: 3.7104 - learning_rate: 0.0010
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 3.6133
# Epoch 16: val_loss improved from 3.70954 to 3.68871, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 197ms/step - loss: 3.6133 - val_loss: 3.6887 - learning_rate: 0.0010
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 3.5972
# Epoch 17: val_loss improved from 3.68871 to 3.67066, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 198ms/step - loss: 3.5972 - val_loss: 3.6707 - learning_rate: 0.0010
# Epoch 18/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - loss: 3.5747
# Epoch 18: val_loss did not improve from 3.67066
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 143ms/step - loss: 3.5717 - val_loss: 3.6713 - learning_rate: 0.0010
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 3.5314
# Epoch 19: val_loss improved from 3.67066 to 3.66208, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 189ms/step - loss: 3.5314 - val_loss: 3.6621 - learning_rate: 0.0010
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 3.5136
# Epoch 20: val_loss did not improve from 3.66208
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 185ms/step - loss: 3.5137 - val_loss: 3.6733 - learning_rate: 0.0010
# Epoch 21/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - loss: 3.4836
# Epoch 21: val_loss did not improve from 3.66208
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - loss: 3.4853 - val_loss: 3.6721 - learning_rate: 0.0010
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 3.4753
# Epoch 22: val_loss improved from 3.66208 to 3.66014, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 193ms/step - loss: 3.4753 - val_loss: 3.6601 - learning_rate: 0.0010
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.4508
# Epoch 23: val_loss improved from 3.66014 to 3.64333, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - loss: 3.4508 - val_loss: 3.6433 - learning_rate: 0.0010
# Epoch 24/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - loss: 3.4087
# Epoch 24: val_loss did not improve from 3.64333
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - loss: 3.4113 - val_loss: 3.6585 - learning_rate: 0.0010
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.4049
# Epoch 25: val_loss did not improve from 3.64333
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 191ms/step - loss: 3.4049 - val_loss: 3.6585 - learning_rate: 0.0010
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.3879
# Epoch 26: val_loss did not improve from 3.64333
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - loss: 3.3879 - val_loss: 3.6644 - learning_rate: 0.0010
# Epoch 27/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - loss: 3.3742
# Epoch 27: val_loss improved from 3.64333 to 3.64075, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - loss: 3.3679 - val_loss: 3.6407 - learning_rate: 2.0000e-04
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 3.3366
# Epoch 28: val_loss improved from 3.64075 to 3.63597, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 187ms/step - loss: 3.3366 - val_loss: 3.6360 - learning_rate: 2.0000e-04
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.3223
# Epoch 29: val_loss did not improve from 3.63597
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 192ms/step - loss: 3.3223 - val_loss: 3.6445 - learning_rate: 2.0000e-04
# Epoch 30/30
# 136/200 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - loss: 3.3208
# Epoch 30: val_loss improved from 3.63597 to 3.63490, saving model to model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - loss: 3.3140 - val_loss: 3.6349 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 30.

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('/kaggle/working/model.keras')

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
def idx_to_word(integer,tokenizer):
    
    for word, index in tokenizer.word_index.items():
        if index==integer:
            return word
    return None

# %%
def predict_caption(model, image, tokenizer, max_length, features):
    
    feature = features[image]
    in_text = "startseq"
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], max_length)

        y_pred = model.predict([feature,sequence])
        y_pred = np.argmax(y_pred)
        
        word = idx_to_word(y_pred, tokenizer)
        
        if word is None:
            break
            
        in_text+= " " + word
        
        if word == 'endseq':
            break
            
    return in_text

# %%
samples = test.sample(15)
samples.reset_index(drop=True,inplace=True)

# %%
for index,record in samples.iterrows():

    img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
    img = img_to_array(img)
    img = img/255.
    
    caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
    samples.loc[index,'caption'] = caption
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
display_images(samples)
